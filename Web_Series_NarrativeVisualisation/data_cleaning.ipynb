# %%
import csv
import os
import sys
import pandas as pd
import numpy as np

# %%
#read the csv file
def read_csv(file):
    data = pd.read_csv(file)
    return data

# %%
file = "TV Series.csv"
df = read_csv(file)
print(df.head())
# Out:
#       Series Title Release Year Runtime                    Genre Rating  \
# 0        Wednesday     (2022– )  45 min   Comedy, Crime, Fantasy    8.2
# 1      Yellowstone     (2018– )  60 min           Drama, Western    8.7
# 2  The White Lotus  (2021–2023)  60 min            Comedy, Drama    7.9
# 3             1923  (2022–2023)  60 min           Drama, Western    8.6
# 4        Jack Ryan     (2018– )  60 min  Action, Drama, Thriller    8.0
#
#                                                 Cast  \
# 0  Jenna Ortega, Hunter Doohan, Percy Hynes White...
# 1  Kevin Costner, Luke Grimes, Kelly Reilly, Wes ...
# 2  Jennifer Coolidge, Jon Gries, F. Murray Abraha...
# 3  Harrison Ford, Helen Mirren, Brandon Sklenar, ...
# 4  John Krasinski, Wendell Pierce, Michael Kelly,...
#
#                                             Synopsis
# 0  Follows Wednesday Addams' years as a student, ...
# 1  A ranching family in Montana faces off against...
# 2  Set in a tropical resort, it follows the explo...
# 3  The Duttons face a new set of challenges in th...
# 4  Up-and-coming CIA analyst, Jack Ryan, is thrus...

# %%
df.shape
# Out:
# (50000, 7)

# %%
df.sample(10)
# Out:
#                       Series Title Release Year Runtime  \
# 23014                  Slow Horses     (2022– )    ****
# 42473          House of the Dragon     (2022– )    ****
# 11952              The White Lotus  (2021–2023)  60 min
# 43278                   Black Snow     (2023– )  52 min
# 24724                    The Crown     (2016– )  58 min
# 42327             Better Call Saul  (2015–2022)  46 min
# 17290                The West Wing  (1999–2006)  44 min
# 20618  Anne Rice's Mayfair Witches     (2023– )    ****
# 3655                     Batwheels     (2022– )  12 min
# 31569                         1899       (2022)  60 min
#
#                               Genre Rating  \
# 23014               Drama, Thriller    7.9
# 42473      Action, Adventure, Drama    8.5
# 11952                 Comedy, Drama    7.9
# 43278                         Crime    7.4
# 24724     Biography, Drama, History    8.7
# 42327                  Crime, Drama    8.9
# 17290                         Drama    8.9
# 20618               Fantasy, Horror    6.8
# 3655   Animation, Action, Adventure    6.4
# 31569                Drama, Mystery    7.4
#
#                                                     Cast  \
# 23014  Gary Oldman, Jack Lowden, Kristin Scott Thomas...
# 42473  Rhys Ifans, Matt Smith, Fabien Frankel, Graham...
# 11952  Jennifer Coolidge, Jon Gries, F. Murray Abraha...
# 43278  Travis Fimmel, Brooke Satchwell, Kestie Morass...
# 24724  Claire Foy, Olivia Colman, Imelda Staunton, Ma...
# 42327  Bob Odenkirk, Rhea Seehorn, Jonathan Banks, Pa...
# 17290  Martin Sheen, Rob Lowe, Allison Janney, John S...
# 20618  Alexandra Daddario, Jack Huston, Tongayi Chiri...
# 3655   Jacob Bertrand, Kimberly Brooks, Mick Wingert,...
# 31569  Emily Beecham, Aneurin Barnard, Andreas Pietsc...
#
#                                                 Synopsis
# 23014  Follows a team of British intelligence agents ...
# 42473  An internal succession war within House Targar...
# 11952  Set in a tropical resort, it follows the explo...
# 43278  In 1995, seventeen-year-old Isabel Baker was m...
# 24724  Follows the political rivalries and romance of...
# 42327  The trials and tribulations of criminal lawyer...
# 17290  Inside the lives of staffers in the West Wing ...
# 20618  Follows a neurosurgeon who discovers she is th...
# 3655   Bam, Redbird, Bibi, Batwing, and Buff are thru...
# 31569  Multinational immigrants traveling from the ol...

# %%
def tweak_imdb_df(df: pd.DataFrame) -> pd.DataFrame:
    return (
        df
        # Formatting column names (Series Title -> series_title)
        .rename(columns=lambda column_: column_.lower().replace(" ", "_"))
        # Replacing "****" values, converting column type and extracting relevant info
        .assign(rating=lambda df_: df_.rating.replace("****", np.NaN).astype("float32"),
                runtime=lambda df_: df_.runtime.replace("****", np.NaN).str.extract(r"(\d+) min").astype("float").astype("Int64"),
                end_year=lambda df_: df_.release_year.str.extract(r"-?(\d+)\)").astype("float").astype("Int64"),
                release_year=lambda df_: df_.release_year.str.extract(r"\((\d+)–?").astype("float").astype("Int64"))
    
        # Dropping series without release year
        .dropna(subset=["release_year"])
        .dropna(subset=["end_year"])

        # Dropping duplicated rows
        .drop_duplicates(subset="series_title")

        .assign(duration= lambda df_: df_.end_year - df_.release_year)
    )

# %%
transformed_df = tweak_imdb_df(df)
print(transformed_df.shape)
transformed_df.sample(3)
# Out:
# (5952, 9)
#             series_title release_year runtime                   genre  rating  \
# 2815        Guilty Party         2021      30  Comedy, Crime, Mystery     5.6
# 3078       The Lucy Show         1962      30                  Comedy     7.2
# 6100  F.C. De Kampioenen         1990      33  Comedy, Romance, Sport     6.7
#
#                                                    cast  \
# 2815  Kate Beckinsale, Jules Latimer, Tiya Sircar, L...
# 3078  Lucille Ball, Gale Gordon, Vivian Vance, Jimmy...
# 6100  Danni Heylen, Marijn De Valck, An Swartenbroek...
#
#                                                synopsis end_year duration
# 2815  A discredited journalist, desperate to salvage...     2021        0
# 3078  The wacky misadventures of a forever-scheming ...     1968        6
# 6100  Oscar Crucke is the coach of substandard enthu...     2020       30

# %%
#create a new df with each genre in a new row and series title, rating, release year and end year
def explode_genres(df: pd.DataFrame) -> pd.DataFrame:
    return (
        df
        .assign(genre=df.genre.str.split(", "))
        .explode("genre")
    )

exploded_df = explode_genres(transformed_df)
print(exploded_df.shape)
exploded_df.sample(3)
# Out:
# (13629, 9)
#                          series_title release_year runtime      genre  rating  \
# 2514                           Gwimul         2021      70      Drama     8.1
# 288                          Gunsmoke         1955      60    Western     8.1
# 868   Jurassic World: Camp Cretaceous         2020      24  Animation     7.5
#
#                                                    cast  \
# 2514  Shin Ha-kyun, Yeo Jin-gu, Choi Dae-hoon, Choi ...
# 288   James Arness, Milburn Stone, Amanda Blake, Ken...
# 868   Paul-Mikél Williams, Kausar Mohammed, Raini Ro...
#
#                                                synopsis end_year duration
# 2514  The story of two fearless men who are willing ...     2021        0
# 288   Marshal Matt Dillon keeps the peace in rough-a...     1975       20
# 868   Six teens attending an adventure camp on the o...     2022        2

# %%
number_of_unique_genres = exploded_df.genre.nunique()
print(f"Number of unique genres: {number_of_unique_genres}")

number_of_unique_release_years = exploded_df.release_year.nunique()
print(f"Number of unique release years: {number_of_unique_release_years}")

#print uniqe genres
unique_genres = exploded_df.genre.unique()
print(unique_genres)
# Out:
# Number of unique genres: 26
# Number of unique release years: 79
# ['Comedy' 'Drama' 'Western' 'Horror' 'Thriller' 'Action' 'Adventure'
#  'Family' 'Mystery' 'Crime' 'Fantasy' 'Documentary' 'History' 'Romance'
#  'Sci-Fi' 'Biography' 'Animation' 'Music' 'Sport' 'War' 'Short'
#  'Reality-TV' 'Musical' 'Talk-Show' 'Game-Show' 'News']

# %%
columns_reodered = ['series_title','runtime','genre','rating', 'release_year', 'end_year','duration', 'cast','synopsis']

# %%
tv_series = exploded_df.reindex(columns = columns_reodered)
tv_series.to_csv('tv_series.csv', index=False)

# %%
print(tv_series.shape)
tv_series.sample(10)
# Out:
# (13629, 9)
#                                            series_title runtime      genre  \
# 2678                                      Weird Science      30     Sci-Fi
# 7362                                           Nobodies      30     Comedy
# 4093  Prince Caspian and the Voyage of the Dawn Treader      30  Adventure
# 1920                                           Lovesick      24     Comedy
# 294                                      The Good Place      22      Drama
# 4216                                       The Returned      42     Horror
# 6747                                         Longstreet      90     Action
# 1929                                    The Client List      42      Drama
# 8328                                 The Nightmare Room      30    Fantasy
# 3163                                    The Last Tycoon      61      Drama
#
#       rating release_year end_year duration  \
# 2678     6.8         1994     1998        4
# 7362     5.9         2017     2018        1
# 4093     7.0         1989     1989        0
# 1920     8.0         2014     2018        4
# 294      8.2         2016     2020        4
# 4216     7.0         2015     2015        0
# 6747     7.9         1971     1972        1
# 1929     6.5         2011     2013        2
# 8328     7.2         2001     2002        1
# 3163     7.6         2016     2017        1
#
#                                                    cast  \
# 2678  Michael Manasseri, John Asher, Vanessa Angel, ...
# 7362  Hugh Davidson, Larry Dorf, Rachel Ramras, Jill...
# 4093  Warwick Davis, Jonathan R. Scott, Sophie Wilco...
# 1920  Johnny Flynn, Antonia Thomas, Daniel Ings, Jos...
# 294   Kristen Bell, William Jackson Harper, Jameela ...
# 4216  Kevin Alejandro, Agnes Bruckner, India Ennenga...
# 6747  James Franciscus, Marlyn Mason, Peter Mark Ric...
# 1929  Jennifer Love Hewitt, Loretta Devine, Colin Eg...
# 8328  James Avery, Keiko Agena, Kyle Gibson, Michael...
# 3163  Matt Bomer, Kelsey Grammer, Lily Collins, Domi...
#
#                                                synopsis
# 2678  Gary Wallace and Wyatt Donnelly create their d...
# 7362  A group of friends works together on a childre...
# 4093  Young Prince Caspian of Narnia wonders and dre...
# 1920  After finding out he has an STD, Dylan must ge...
# 294   Four people and their otherworldly frienemy st...
# 4216  A small town's residents are stunned when rece...
# 6747       The cases of a blind insurance investigator.
# 1929  Riley is a single mother living in a small Tex...
# 8328  Anthology series centered on teens facing supe...
# 3163  Centers on Hollywood's first wunderkind studio...

# %%
#number of unique series_title with rating greater than 8

number_of_unique_series_title = tv_series[tv_series.rating > 8.5].series_title.nunique()
print(f"Number of unique series title with rating greater than 8: {number_of_unique_series_title}")
# Out:
# Number of unique series title with rating greater than 8: 275

# %%
file2 = "movies.csv"
df2 = read_csv(file2)
df2.sample(10)
# Out:
#      Rank   Movie_ID                   Movie_Name  \
# 575   576  tt0119116            The Fifth Element
# 350   351  tt0106977                 The Fugitive
# 156   157  tt0381061                Casino Royale
# 79     80  tt1375666                    Inception
# 926   927  tt1001508  He's Just Not That Into You
# 834   835  tt0258000                   Panic Room
# 283   284  tt1502397            Bad Boys for Life
# 705   706  tt0489099                       Jumper
# 682   683  tt0425061                    Get Smart
# 100   101  tt0382625            The Da Vinci Code
#
#                         Director  Year           US_Distributor  \
# 575                   Luc Besson  1997  Sony Pictures Releasing
# 350                 Andrew Davis  1993             Warner Bros.
# 156              Martin Campbell  2006  Sony Pictures Releasing
# 79             Christopher Nolan  2010             Warner Bros.
# 926                   Ken Kwapis  2009             Warner Bros.
# 834                David Fincher  2002  Sony Pictures Releasing
# 283  Adil El Arbi, Bilall Fallah  2020  Sony Pictures Releasing
# 705                   Doug Liman  2008    Twentieth Century Fox
# 682                  Peter Segal  2008             Warner Bros.
# 100                   Ron Howard  2006  Sony Pictures Releasing
#
#      Lifetime_Gross        Budget   MPAA Running_Time  \
# 575       264029966           NaN  PG-13   2 hr 6 min
# 350       368875760           NaN  PG-13  2 hr 10 min
# 156       616501619  $150,000,000  PG-13  2 hr 24 min
# 79        829895144  $160,000,000  PG-13  2 hr 28 min
# 926       178866158           NaN  PG-13   2 hr 9 min
# 834       197079546   $48,000,000      R  1 hr 52 min
# 283       419074646   $90,000,000      R   2 hr 4 min
# 705       225132113   $85,000,000  PG-13  1 hr 28 min
# 682       230685453   $80,000,000  PG-13  1 hr 50 min
# 100       760006945  $125,000,000  PG-13  2 hr 29 min
#
#                                        Genre
# 575                Action, Adventure, Sci-Fi
# 350  Action, Crime, Drama, Mystery, Thriller
# 156              Action, Adventure, Thriller
# 79       Action, Adventure, Sci-Fi, Thriller
# 926                   Comedy, Drama, Romance
# 834                   Crime, Drama, Thriller
# 283          Action, Comedy, Crime, Thriller
# 705      Action, Adventure, Sci-Fi, Thriller
# 682                Action, Adventure, Comedy
# 100                        Mystery, Thriller
